# %% [markdown]
# * This notebook will pre-process images for training and test
# * This will prepare multi-label one-hot-encoding for labels
# * This will resize images to 64x64 and save a batch of 1000 images in a pickle file
# * Assumption - Needs following dir structure
# * Directory structure -
#    *  ../data - top layer directory for images
#    *  ../data/train_v2.csv  - csv file for training images
#    *  ../data/train-jpg - dir for training images
#    *  ../data/test-jpg -  dir for testing images
#    *  ../data/test-jpg-additional - dir for additional testing images

# %%
import os
import pandas as pd
import cv2
from pprint import pprint
import numpy as np
from itertools import chain
import pickle

# %%
"""
data is kept one level up
"""
data_root_folder = os.path.abspath("../data/")
train_root_dir=os.path.join(data_root_folder, 'train-jpg')
train_csv_file = os.path.join(data_root_folder, 'train_v2.csv')

# %%
"""
This routine makes a dictionary of all unique and sorted labels.
The labels are entered as keys with  corresponding indexs as values. 
"""
def make_label_map():

    train_csv_df = pd.read_csv(train_csv_file)

    #print (train_csv_df.head())

    labels = sorted(set(chain.from_iterable([tags.split(" ") for tags in train_csv_df['tags'].values])))

    #print (labels)

    label_map = dict()

    for index, label in enumerate(labels):
        label_map[label] = index

    
    return label_map

label_map = make_label_map()
pprint(label_map)

# %%
"""
This function will read image into an array from image file 
This will resize each image and normalize by dividing with 255.0
"""

def read_image(image_filename, image_resize):
    """
    :param_args: list of arguments
        image_file_name: string
            The image file name
        image_resize: tuple (int, int)
            The resize dimension
    """

    #print image_name
    
    print image_filename
    image_array = cv2.imread(image_filename)

    # convert to RGB
    image_array = cv2.cvtColor(image_array, cv2.COLOR_BGR2RGB)
    # resize
    image_array = cv2.resize(image_array, image_resize)
    # normalize
    image_array = image_array.astype(float) / 255.0
    return image_array

#unit-test
data_root_folder = os.path.abspath("../data/")
dir_path = os.path.join(data_root_folder, 'train-jpg')
test_image_name = os.path.join(dir_path, 'train_0.jpg')

test_image_resize = (64, 64)
test_image = read_image(test_image_name, test_image_resize)
print test_image.shape

# %%
"""
This function is one hot encoder for multiple labels in tags
""" 
def multi_label_one_hot(tags, label_map):
    ml_one_hot = np.zeros(len(label_map))
    for label in tags.split(' '):
        if label in label_map:
            ml_one_hot[label_map[label]] = 1
    return ml_one_hot

# unit-test 
test_tags = "haze primary"
test_label_map = make_label_map()
test_ml_oh = multi_label_one_hot (test_tags, test_label_map)

print test_ml_oh

# %%
"""
This function will read and store training images in a pickle file
The input is a dataframe that contains the image filename and corresponding labels
The pickle file will contain both the image data and the label in two distinct arrays
"""

def pickle_train_images(train_image_root_dir, df, pickle_filename, image_resize = (64, 64)):
   
    features = []
    labels = []
   
    for index, row in df.iterrows():
        
        image_name = row['image_name']
        tags = row['tags']
        
        print image_name, tags

        image_file_name = os.path.join(train_image_root_dir, image_name + '.jpg')

        image = read_image(image_file_name, image_resize)
        features.append(image)
        labels.append(multi_label_one_hot(tags, label_map))
            
    print 'pickle_filename = ', pickle_filename
    pickle.dump((features, labels), open(pickle_filename, 'wb'))

# %%
"""
This function will read and store test images  in a pickle file
This code will go by the list of input filenames and store the image in a pickle file
The pickle file will contain both the image data and the image file name in two distinct arrays
"""



def pickle_test_images(filenames, pickle_filename, image_resize = (64, 64)):
    
    test_features = []
    for image_filename in filenames:
        
        print 'image_filename = ', image_filename

        image = read_image(image_filename, image_resize)
        
        test_features.append(image)


    print 'pickle_filename = ', pickle_filename
    
    pickle.dump((filenames, test_features), open(pickle_filename, 'wb'))

# %%
"""
This function will read and store training images  in batches in a pickle file
The input is a pickle batch size - which is different from training batch size
This will create a batch of filenames and repeatedly call pickle_train_images for each batch
"""


#### Pickle batch size is different from training batch size

def make_train_batches(label_map, pickle_batch_size, image_resize = (64, 64), testing_limit=None):
    
    #print 'image_resize=', image_resize, 'train_valid_split=', train_valid_split
    
    df = pd.read_csv(train_csv_file)
    
    print 'total training images = ', len(df )
     
    df = df[:testing_limit]  # This is a quick-hack to unit test this function
      
    train = df
    
    print 'total training images = ', len(train )
         
    # first pickle pre-processed training images - in batches determined by pickle_batch_size
    batch_id = 0
    for start in range(0, len(train), pickle_batch_size):
        end = min(start + pickle_batch_size, len(train))
                        
        pickle_train_images(train_root_dir, train[start:end], 'train_batch.{}.p'.format(batch_id))
        batch_id += 1
        
#unit-test          
make_train_batches(label_map, 3, testing_limit = 10)

# %%
"""
generators for batches of image data and corresponding labels
"""


def batch_features_labels(features, labels, batch_size):
    """
    Split features and labels into batches
    """
    for start in range(0, len(features), batch_size):
        end = min(start + batch_size, len(features))
        yield features[start:end], labels[start:end]


"""
This routine will load a training set from pickle file
This will then generate the training  batches out of the data
"""

def load_preprocess_training_batch(batch_id, batch_size):
    """
    Load the Preprocessed Training data and return them in batches of <batch_size> or less
    """
    filename = 'train_batch.{}.p'.format(batch_id)
    print filename
    features, labels = pickle.load(open(filename, mode='rb'))
    #print 'feature=', features, "labels=", labels

    # Return the training data in batches of size <batch_size> or less
    return batch_features_labels(features, labels, batch_size)

# %%
"""
This function will read and store test images  in batches in a pickle file
The input is a pickle batch size - which is different from training batch size
This will read images from test and additional test directories
This will create pickle file for each batch determined by  pickle_batch_size
"""
#### Pickle batch size is different from training batch size

def make_test_batches(pickle_batch_size, image_resize = (64, 64), testing_limit = None):
   
    data_root_folder = os.path.abspath("../data/")
    dir_path = os.path.join(data_root_folder, 'test-jpg')

    file_names = os.listdir(dir_path)
    
    print 'number of files = ', len(file_names)
    
    test_filepaths = []
    for filename in file_names:
        test_filepaths.append(os.path.join(dir_path, filename))
    
    # now for jpg_additional
    dir_path = os.path.join(data_root_folder, 'test-jpg-additional')
    
    file_names = os.listdir(dir_path)
    
    print 'number of files = ', len(file_names)
    
    for filename in file_names:
        test_filepaths.append(os.path.join(dir_path, filename))
        
    print 'total testing images = ', len(test_filepaths )
    
    # some hack for testing
    test_filepaths = test_filepaths[:testing_limit]
    
    print 'total testing images = ', len(test_filepaths )
         
    #  pickle pre-processed test images - in batches determined by pickle_batch_size
    batch_id = 0
    for start in range(0, len(test_filepaths), pickle_batch_size):
        end = min(start + pickle_batch_size, len(test_filepaths))
                        
        pickle_test_images(test_filepaths[start:end], 'test_batch.{}.p'.format(batch_id))
        batch_id += 1



# unit-test          
make_test_batches(3, testing_limit = 10)

# %%
"""
Run this cell to pre-process all training data
"""

# pickle batch size = 1000
label_map = make_label_map()

make_train_batches(label_map, pickle_batch_size=1000, image_resize = (64, 64))
# Out:
# total training images =  40479
# total training images =  40479
# train_0 haze primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_0.jpg
# train_1 agriculture clear primary water
# /Users/amitabhac/Kaggle/data/train-jpg/train_1.jpg
# train_2 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_2.jpg
# train_3 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3.jpg
# train_4 agriculture clear habitation primary road
# /Users/amitabhac/Kaggle/data/train-jpg/train_4.jpg
# train_5 haze primary water
# /Users/amitabhac/Kaggle/data/train-jpg/train_5.jpg
# train_6 agriculture clear cultivation primary water
# /Users/amitabhac/Kaggle/data/train-jpg/train_6.jpg
# train_7 haze primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_7.jpg
# train_8 agriculture clear cultivation primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_8.jpg
# train_9 agriculture clear cultivation primary road
# /Users/amitabhac/Kaggle/data/train-jpg/train_9.jpg
# train_10 agriculture clear primary slash_burn water
# /Users/amitabhac/Kaggle/data/train-jpg/train_10.jpg
# train_11 clear primary water
# /Users/amitabhac/Kaggle/data/train-jpg/train_11.jpg
# train_12 cloudy
# /Users/amitabhac/Kaggle/data/train-jpg/train_12.jpg
# train_13 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_13.jpg
# train_14 cloudy
# /Users/amitabhac/Kaggle/data/train-jpg/train_14.jpg
# train_15 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_15.jpg
# train_16 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_16.jpg
# train_17 partly_cloudy primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_17.jpg
# train_18 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_18.jpg
# train_19 agriculture clear primary road
# /Users/amitabhac/Kaggle/data/train-jpg/train_19.jpg
# train_20 agriculture clear primary water
# /Users/amitabhac/Kaggle/data/train-jpg/train_20.jpg
# train_21 clear primary road water
# /Users/amitabhac/Kaggle/data/train-jpg/train_21.jpg
# train_22 partly_cloudy primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_22.jpg
# train_23 agriculture clear primary road
# /Users/amitabhac/Kaggle/data/train-jpg/train_23.jpg
# train_24 conventional_mine partly_cloudy primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_24.jpg
# train_25 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_25.jpg
# train_26 cloudy
# /Users/amitabhac/Kaggle/data/train-jpg/train_26.jpg
# train_27 agriculture partly_cloudy primary water
# /Users/amitabhac/Kaggle/data/train-jpg/train_27.jpg
# train_28 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_28.jpg
# train_29 partly_cloudy primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_29.jpg
# train_30 clear primary water
# /Users/amitabhac/Kaggle/data/train-jpg/train_30.jpg
# train_31 clear cultivation primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_31.jpg
# train_32 agriculture clear primary road
# /Users/amitabhac/Kaggle/data/train-jpg/train_32.jpg
# train_33 agriculture cultivation partly_cloudy primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_33.jpg
# train_34 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_34.jpg
# train_35 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_35.jpg
# train_36 agriculture clear primary road
# /Users/amitabhac/Kaggle/data/train-jpg/train_36.jpg
# train_37 partly_cloudy primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_37.jpg
# train_38 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_38.jpg
# train_39 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_39.jpg
# train_40 agriculture clear cultivation primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_40.jpg
# train_41 agriculture clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_41.jpg
# train_42 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_42.jpg
# train_43 bare_ground haze
# /Users/amitabhac/Kaggle/data/train-jpg/train_43.jpg
# train_44 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_44.jpg
# train_45 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_45.jpg
# train_46 bare_ground clear habitation primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_46.jpg
# train_47 clear primary water
# /Users/amitabhac/Kaggle/data/train-jpg/train_47.jpg
# train_48 clear primary water
# /Users/amitabhac/Kaggle/data/train-jpg/train_48.jpg
# train_49 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_49.jpg
# train_50 cloudy
# /Users/amitabhac/Kaggle/data/train-jpg/train_50.jpg
# train_51 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_51.jpg
# train_52 agriculture clear habitation primary road water
# /Users/amitabhac/Kaggle/data/train-jpg/train_52.jpg
# train_53 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_53.jpg
# train_54 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_54.jpg
# train_55 partly_cloudy primary road water
# /Users/amitabhac/Kaggle/data/train-jpg/train_55.jpg
# train_56 clear primary water
# /Users/amitabhac/Kaggle/data/train-jpg/train_56.jpg
# train_57 artisinal_mine bare_ground clear primary water
# /Users/amitabhac/Kaggle/data/train-jpg/train_57.jpg
# train_58 agriculture clear primary road
# /Users/amitabhac/Kaggle/data/train-jpg/train_58.jpg
# train_59 agriculture clear habitation primary road
# /Users/amitabhac/Kaggle/data/train-jpg/train_59.jpg
# train_60 haze primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_60.jpg
# train_61 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_61.jpg
# train_62 clear primary water
# /Users/amitabhac/Kaggle/data/train-jpg/train_62.jpg
# train_63 agriculture clear primary road
# /Users/amitabhac/Kaggle/data/train-jpg/train_63.jpg
# train_64 agriculture clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_64.jpg
# train_65 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_65.jpg
# train_66 agriculture clear primary road
# /Users/amitabhac/Kaggle/data/train-jpg/train_66.jpg
# train_67 clear habitation primary road
# /Users/amitabhac/Kaggle/data/train-jpg/train_67.jpg
# train_68 cloudy
# /Users/amitabhac/Kaggle/data/train-jpg/train_68.jpg
# train_69 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_69.jpg
# train_70 blooming clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_70.jpg
# train_71 clear primary water
# /Users/amitabhac/Kaggle/data/train-jpg/train_71.jpg
# train_72 cloudy
# /Users/amitabhac/Kaggle/data/train-jpg/train_72.jpg
# train_73 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_73.jpg
# train_74 agriculture partly_cloudy primary road
# /Users/amitabhac/Kaggle/data/train-jpg/train_74.jpg
# train_75 agriculture clear primary road water
# /Users/amitabhac/Kaggle/data/train-jpg/train_75.jpg
# train_76 partly_cloudy primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_76.jpg
# train_77 cloudy
# /Users/amitabhac/Kaggle/data/train-jpg/train_77.jpg
# train_78 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_78.jpg
# train_79 clear cultivation primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_79.jpg
# train_80 agriculture partly_cloudy primary road
# /Users/amitabhac/Kaggle/data/train-jpg/train_80.jpg
# train_81 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train
clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3370.jpg
# train_3371 partly_cloudy primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3371.jpg
# train_3372 clear primary road water
# /Users/amitabhac/Kaggle/data/train-jpg/train_3372.jpg
# train_3373 partly_cloudy primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3373.jpg
# train_3374 agriculture clear primary road water
# /Users/amitabhac/Kaggle/data/train-jpg/train_3374.jpg
# train_3375 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3375.jpg
# train_3376 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3376.jpg
# train_3377 agriculture clear habitation primary road
# /Users/amitabhac/Kaggle/data/train-jpg/train_3377.jpg
# train_3378 partly_cloudy primary water
# /Users/amitabhac/Kaggle/data/train-jpg/train_3378.jpg
# train_3379 haze primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3379.jpg
# train_3380 partly_cloudy primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3380.jpg
# train_3381 agriculture partly_cloudy primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3381.jpg
# train_3382 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3382.jpg
# train_3383 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3383.jpg
# train_3384 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3384.jpg
# train_3385 agriculture clear primary slash_burn
# /Users/amitabhac/Kaggle/data/train-jpg/train_3385.jpg
# train_3386 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3386.jpg
# train_3387 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3387.jpg
# train_3388 agriculture partly_cloudy primary water
# /Users/amitabhac/Kaggle/data/train-jpg/train_3388.jpg
# train_3389 agriculture clear cultivation primary road
# /Users/amitabhac/Kaggle/data/train-jpg/train_3389.jpg
# train_3390 agriculture haze primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3390.jpg
# train_3391 agriculture partly_cloudy primary road
# /Users/amitabhac/Kaggle/data/train-jpg/train_3391.jpg
# train_3392 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3392.jpg
# train_3393 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3393.jpg
# train_3394 haze primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3394.jpg
# train_3395 cloudy
# /Users/amitabhac/Kaggle/data/train-jpg/train_3395.jpg
# train_3396 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3396.jpg
# train_3397 haze primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3397.jpg
# train_3398 haze primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3398.jpg
# train_3399 agriculture clear cultivation primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3399.jpg
# train_3400 agriculture clear habitation primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3400.jpg
# train_3401 haze primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3401.jpg
# train_3402 partly_cloudy primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3402.jpg
# train_3403 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3403.jpg
# train_3404 agriculture clear habitation primary road
# /Users/amitabhac/Kaggle/data/train-jpg/train_3404.jpg
# train_3405 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3405.jpg
# train_3406 cloudy
# /Users/amitabhac/Kaggle/data/train-jpg/train_3406.jpg
# train_3407 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3407.jpg
# train_3408 artisinal_mine clear primary water
# /Users/amitabhac/Kaggle/data/train-jpg/train_3408.jpg
# train_3409 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3409.jpg
# train_3410 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3410.jpg
# train_3411 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3411.jpg
# train_3412 agriculture clear habitation primary road water
# /Users/amitabhac/Kaggle/data/train-jpg/train_3412.jpg
# train_3413 haze primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3413.jpg
# train_3414 clear primary
# /Users/amitabhac/Kaggle/data/train-jpg/train_3414.jpg
# train_3415 artisinal_mine bare_ground clear habitation primary road water
# /Users/amitabhac/Kaggle/data/train-jpg/train_3415.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-ba55e50d6a9e> in <module>()
#       4 label_map = make_label_map()
#       5
# ----> 6 make_train_batches(label_map, pickle_batch_size=1000, image_resize = (64, 64))
#
# <ipython-input-25-78d6ff58ec80> in make_train_batches(label_map, pickle_batch_size, image_resize, testing_limit)
#      20         end = min(start + pickle_batch_size, len(train))
#      21
# ---> 22         pickle_train_images(train_root_dir, train[start:end], 'train_batch.{}.p'.format(batch_id))
#      23         batch_id += 1
#      24
#
# <ipython-input-23-7c734212ad06> in pickle_train_images(train_image_root_dir, df, pickle_filename, image_resize)
#      13         image_file_name = os.path.join(train_image_root_dir, image_name + '.jpg')
#      14
# ---> 15         image = read_image(image_file_name, image_resize)
#      16         features.append(image)
#      17         labels.append(multi_label_one_hot(tags, label_map))
#
# <ipython-input-29-4c441c7f6b99> in read_image(image_filename, image_resize)
#      12
#      13     print image_filename
# ---> 14     image_array = cv2.imread(image_filename)
#      15
#      16     # convert to RGB
#
# KeyboardInterrupt:

# %%
"""
Run this cell to pre-process all test data
"""

# pickle batch size = 1000

make_test_batches(pickle_batch_size=1000, image_resize = (64, 64))
